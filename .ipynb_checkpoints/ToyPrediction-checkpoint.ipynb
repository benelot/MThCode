# %%
# RNN and FFNN for Toy data
# Segessenmann J. 2020

import matplotlib.pyplot as plt
import numpy as np
import time
import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ## Generate Data
# Three sinus waves are generated with variation in their phase. The model predicts one wave from the other two.
# The train Data X_train is a list with each entry of shape (window_size=50, channels=2) and Y_train a list with each entry of shape (window_size=50, channels=1). The window is iterating trough the samples of length N_samples=1000.

# %%
N_samples = 1000
N_turns = 4
x0 = np.sin(np.arange(0, N_turns*2*np.pi, N_turns*2*np.pi/N_samples))
x1 = np.cos(np.arange(0, N_turns*2*np.pi, N_turns*2*np.pi/N_samples))
x2 = np.sin(np.arange(-0.8, N_turns*2*np.pi-0.8, N_turns*2*np.pi/N_samples))
data = np.array([x0, x1, x2]).transpose()
plt.figure()
plt.plot(data)

# to tensor
data = torch.FloatTensor(data)

# split data
train_portion = 0.8
train_set = data[:int(train_portion * N_samples), :]
test_set = data[int(train_portion * N_samples):, :]

# prepare data for learning
window_size = 50
ch_in = [0, 1]
ch_out = [2]
X_train, Y_train, X_test, Y_test = [], [], [], []
for i in range(train_set.shape[0] - window_size):
    X_train.append(train_set[i:i+window_size, ch_in])
    Y_train.append(train_set[i+window_size-1, ch_out])
for i in range(test_set.shape[0] - window_size):
    X_test.append(test_set[i:i+window_size, ch_in])
    Y_test.append(test_set[i+window_size-1, ch_out])

# %% [markdown]
# ## RNN
# Vanilla RNN with two input nodes and one hidden layer node. The hidden layer node is the output as well.

# %%
class RNN(nn.Module):
    def __init__(self, input_size=len(ch_in), hidden_size=8):
        super().__init__()
        # Variables
        self.hidden_size = hidden_size
        # Layers
        self.rnn = nn.RNN(input_size, hidden_size)      

    def forward(self, X):
        # Inizialize hidden node
        self.hidden = torch.zeros(1, 1, self.hidden_size)
        # Forward path
        _, self.hidden = self.rnn(X.view(X.shape[0], 1, X.shape[1]), self.hidden)
        return self.hidden[0,0,-1]  # last value of each output channel

# %%
model = RNN()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
epochs = 30

temp_loss = []
epoch_loss = []

start_time = time.time()

for epoch in range(epochs):
    for idx, X in enumerate(X_train):
        optimizer.zero_grad()
        Y_pred = model(X)
        loss = criterion(Y_pred, Y_train[idx][0])
        loss.backward()
        optimizer.step()
        temp_loss.append(loss.item())

    epoch_loss.append(np.mean(np.asarray(temp_loss)))
    print(f'Epoch: {epoch} Loss: {epoch_loss[epoch]}')

total_time = time.time() - start_time
print('Time used [s]: ' + str(total_time))

plt.figure()
plt.plot(np.asarray(epoch_loss))
plt.xlabel('epoch'), plt.ylabel('loss')
# Out:
# Epoch: 0 Loss: 0.09317368803003354
# Epoch: 1 Loss: 0.10885688484185176
# Epoch: 2 Loss: 0.09750438798349552
# Epoch: 3 Loss: 0.09127479614836892
# Epoch: 4 Loss: 0.08465844041031716
# Epoch: 5 Loss: 0.07748057782658327
# Epoch: 6 Loss: 0.07028435589201165
# Epoch: 7 Loss: 0.06310055599438039
# Epoch: 8 Loss: 0.05669288774144493
# Epoch: 9 Loss: 0.05136557164270744
# Epoch: 10 Loss: 0.0469850286249444
# Epoch: 11 Loss: 0.04333601893353888
# Epoch: 12 Loss: 0.04024046823714457
# Epoch: 13 Loss: 0.03757882813648446
# Epoch: 14 Loss: 0.03526222442450029
# Epoch: 15 Loss: 0.03322152116531695
# Epoch: 16 Loss: 0.03140253420882531
# Epoch: 17 Loss: 0.029765163804297008
# Epoch: 18 Loss: 0.028280628996511594
# Epoch: 19 Loss: 0.026931163989954182
# Epoch: 20 Loss: 0.025700596667252922
# Epoch: 21 Loss: 0.0245775158295683
# Epoch: 22 Loss: 0.023549144981738792
# Epoch: 23 Loss: 0.02260479563312871
# Epoch: 24 Loss: 0.021735462333841125
# Epoch: 25 Loss: 0.020932133054641457
# Epoch: 26 Loss: 0.020187459230835612
# Epoch: 27 Loss: 0.01949512682032041
# Epoch: 28 Loss: 0.018849656229847647
# Epoch: 29 Loss: 0.018246236530109414
# Time used [s]: 99.86095118522644
# (Text(0.5, 0, 'epoch'), Text(0, 0.5, 'loss'))

# %%
model.eval()

Y_preds = []
for idx, X in enumerate(X_test):
    with torch.no_grad():
        model.hidden = torch.zeros(1, 1, model.hidden_size)
        Y_preds.append(model(X).numpy())

preds = np.asarray(Y_preds)
Y_test_np = np.asarray([idx.numpy() for idx in Y_test])

fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(Y_test_np[:], label='true')
ax.plot(preds[:], label='predicted')
ax.legend()

[(para[0],para[1]) for para in list(model.rnn.named_parameters())]
# Out:
# [('weight_ih_l0', Parameter containing:
#   tensor([[ 0.4703, -0.6707],
#           [-0.1265,  0.0578],
#           [-0.5653, -0.6222],
#           [-0.3604,  0.2771],
#           [-0.0586, -0.6014],
#           [-0.6624,  0.0334],
#           [ 0.3570, -0.6641],
#           [ 1.0699,  0.1031]], requires_grad=True)),
#  ('weight_hh_l0', Parameter containing:
#   tensor([[-0.0642, -0.3182,  0.3984, -0.0463,  0.1261,  0.3146,  0.5076,  0.3787],
#           [ 0.2787, -0.2058,  0.0852,  0.5762,  0.1118,  0.6060,  0.0186, -0.0535],
#           [ 0.1099, -0.3753,  1.1898, -0.3677,  0.8152, -0.8773,  0.0744, -0.2004],
#           [-0.1690, -0.1191, -0.1590, -0.1124, -0.4800,  0.2326, -0.0592,  0.1936],
#           [ 0.2955, -0.0519,  0.3992, -0.5770,  0.5580, -0.5375,  0.2009,  0.1337],
#           [ 0.1928, -0.5425, -0.4754, -0.1615, -0.1182, -0.2042, -0.2150,  0.5272],
#           [ 0.3125,  0.1719,  0.0162,  0.1483,  0.5376, -0.0311,  0.3964, -0.0144],
#           [ 0.2760, -0.0914,  0.1222, -0.2024,  0.1576, -0.2318,  0.2443,  0.1800]],
#          requires_grad=True)),
#  ('bias_ih_l0', Parameter containing:
#   tensor([-0.0180,  0.0011,  0.0238, -0.0801, -0.2289,  0.0465,  0.0363, -0.0918],
#          requires_grad=True)),
#  ('bias_hh_l0', Parameter containing:
#   tensor([ 0.1619, -0.0315,  0.0217,  0.2772,  0.3024, -0.0205, -0.1207,  0.1000],
#          requires_grad=True))]

# %% [markdown]
# ## FFNN
# Same architecture as RNN. The number of fully connected layers is window_size=50, so its a 50-layer FFNN with shared parameters (the same layer is used 50 times). Input nodes and hidden nodes are concatenated.

# %%
class FFNN(nn.Module):
    def __init__(self, window_size=window_size, input_channel_size=len(ch_in), hidden_size=8):
        super().__init__()
        # Variables
        self.hidden_size = hidden_size
        self.input_channel_size = input_channel_size
        # Create FC Layer
        self.fc = nn.Linear(self.input_channel_size + self.hidden_size, self.hidden_size)
        
    def forward(self, X):
        # Initialize hidden node
        h = torch.zeros(self.hidden_size, dtype=torch.float32)
        # Forward path
        for i in range(X.shape[0]):
            fc_in = torch.cat((X[i,:], h), 0)
            h = F.relu(self.fc(fc_in))
        return torch.tanh(h[6:7])

# %%
model = FFNN()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
epochs = 30

temp_loss = []
epoch_loss = []

start_time = time.time()

for epoch in range(epochs):
    for idx, X in enumerate(X_train):
        optimizer.zero_grad()
        Y_pred = model(X)
        loss = criterion(Y_pred, Y_train[idx])
        loss.backward()
        optimizer.step()
        temp_loss.append(loss.item())

    epoch_loss.append(np.mean(np.asarray(temp_loss)))
    print(f'Epoch: {epoch} Loss: {epoch_loss[epoch]}')
    
total_time = time.time() - start_time
print('Time used [s]: ' + str(total_time))

plt.figure()
plt.plot(np.asarray(epoch_loss))
plt.xlabel('epoch'), plt.ylabel('loss')
# Out:
# Epoch: 0 Loss: 0.5002158500367611
# Epoch: 1 Loss: 0.5001079246018538
# Epoch: 2 Loss: 0.5000719494568847
# Epoch: 3 Loss: 0.5000539618844001
# Epoch: 4 Loss: 0.5000431693409094
# Epoch: 5 Loss: 0.5000359743119156
# Epoch: 6 Loss: 0.5000308350054914
# Epoch: 7 Loss: 0.5000269805256733
# Epoch: 8 Loss: 0.5000239825969259
# Epoch: 9 Loss: 0.500021584253928
# Epoch: 10 Loss: 0.5000196219732933
# Epoch: 11 Loss: 0.5000179867394311
# Epoch: 12 Loss: 0.5000166030800092
# Epoch: 13 Loss: 0.500015417086219
# Epoch: 14 Loss: 0.5000143892249341
# Epoch: 15 Loss: 0.5000134898463099
# Epoch: 16 Loss: 0.5000126962769356
# Epoch: 17 Loss: 0.5000119908819362
# Epoch: 18 Loss: 0.500011359739042
# Epoch: 19 Loss: 0.5000107917104373
# Epoch: 20 Loss: 0.5000102777797948
# Epoch: 21 Loss: 0.50000981057012
# Epoch: 22 Loss: 0.5000093839873733
# Epoch: 23 Loss: 0.5000089929531888
# Epoch: 24 Loss: 0.500008633201739
# Epoch: 25 Loss: 0.5000083011234778
# Epoch: 26 Loss: 0.5000079936436063
# Epoch: 27 Loss: 0.5000077081265828
# Epoch: 28 Loss: 0.5000074423003884
# Epoch: 29 Loss: 0.5000071941959403
# Time used [s]: 122.26617240905762
# (Text(0.5, 0, 'epoch'), Text(0, 0.5, 'loss'))

# %%
model.eval()

Y_preds = []
for idx, X in enumerate(X_test):
    with torch.no_grad():
        Y_preds.append(model(X).numpy())

preds = np.asarray(Y_preds)
Y_test_np = np.asarray([idx.numpy() for idx in Y_test])

fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(Y_test_np[:,0], label='true')
ax.plot(preds[:,0], label='predicted')
ax.legend()

print('Weights: ' + str(model.fc.weight.data))
print('Bias: ' + str(model.fc.bias.data))
# Out:
# Weights: tensor([[-0.0234, -0.6529,  0.8751, -0.5007, -0.2303, -0.7358,  0.4927, -0.5871,
#          -0.2963,  0.7095],
#         [-0.0298,  0.6121, -0.4905,  0.3759,  0.0509,  0.5834, -0.1718,  0.1885,
#          -0.1617, -0.4136],
#         [-0.6534,  0.5220, -0.3522,  0.3887,  0.0537, -0.0386,  0.1130, -0.5488,
#           0.2352, -0.0552],
#         [-0.2159,  0.8260, -0.5169,  0.0203,  0.3542,  0.2961, -0.0865,  0.1245,
#          -0.6294,  0.1830],
#         [ 0.3557, -0.0670,  0.1187, -0.2085, -0.4032, -0.5017,  0.0682,  0.0183,
#          -0.4174,  0.4453],
#         [-0.5743, -0.3507, -0.4903, -0.0760, -0.1258, -0.1890, -0.1909,  0.4885,
#           0.4395, -0.3835],
#         [ 1.2213,  0.2170,  0.1092, -0.1860, -0.4865, -0.2984,  0.3171, -0.2231,
#           0.0166, -0.0817],
#         [ 0.0114,  0.2393,  0.1092, -0.3777, -0.0681,  0.0013,  0.0288, -0.6330,
#          -0.2618, -0.2534]])
# Bias: tensor([ 0.1098, -0.0608, -0.1337,  0.1716,  0.1902,  0.0024, -0.0553, -0.2355])
